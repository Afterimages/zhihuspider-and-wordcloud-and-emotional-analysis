# %%
import requests
import pandas as pd
import re
import time
import random
 
df = pd.DataFrame()
headers ={
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36'
}
 
for page in range(0,25,3):
    url = f'https://www.zhihu.com/api/v4/questions/488891947/answers?include=data[*].is_normal,admin_closed_comment,reward_info,is_collapsed,annotation_action,annotation_detail,collapse_reason,is_sticky,collapsed_by,suggest_edit,comment_count,can_comment,content,editable_content,attachment,voteup_count,reshipment_settings,comment_permission,created_time,updated_time,review_info,relevant_info,question,excerpt,is_labeled,paid_info,paid_info_content,relationship.is_authorized,is_author,voting,is_thanked,is_nothelp,is_recognized;data[*].mark_infos[*].url;data[*].author.follower_count,vip_info,badge[*].topics;data[*].settings.table_of_content.enabled&limit=5&offset={page}&platform=desktop&sort_by=default'    
    #url = f'https://www.zhihu.com/api/v4/questions/499739058/answers?include=data%5B%2A%5D.is_normal%2Cadmin_closed_comment%2Creward_info%2Cis_collapsed%2Cannotation_action%2Cannotation_detail%2Ccollapse_reason%2Cis_sticky%2Ccollapsed_by%2Csuggest_edit%2Ccomment_count%2Ccan_comment%2Ccontent%2Ceditable_content%2Cattachment%2Cvoteup_count%2Creshipment_settings%2Ccomment_permission%2Ccreated_time%2Cupdated_time%2Creview_info%2Crelevant_info%2Cquestion%2Cexcerpt%2Cis_labeled%2Cpaid_info%2Cpaid_info_content%2Crelationship.is_authorized%2Cis_author%2Cvoting%2Cis_thanked%2Cis_nothelp%2Cis_recognized%3Bdata%5B%2A%5D.mark_infos%5B%2A%5D.url%3Bdata%5B%2A%5D.author.follower_count%2Cvip_info%2Cbadge%5B%2A%5D.topics%3Bdata%5B%2A%5D.settings.table_of_content.enabled&limit=5&offset={page}&platform=desktop&sort_by=default'

    response = requests.get(url,headers=headers).json()
    data = response['data']
    for list_ in data:
        name = list_['author']['name']  # 知乎作者
        id_ = list_['author']['id']  # 作者id
        created_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(list_['created_time'] )) # 回答时间
        voteup_count = list_['voteup_count']  # 赞同数
        comment_count = list_['comment_count']  # 底下评论数
        content = list_['content']  # 回答内容
        content = ''.join(re.findall("[\u3002\uff1b\uff0c\uff1a\u201c\u201d\uff08\uff09\u3001\uff1f\u300a\u300b\u4e00-\u9fa5]", content))  # 正则表达式提取
        dataFrame = pd.DataFrame(
            {'知乎作者': [name], '作者id': [id_], '回答时间': [created_time], '赞同数': [voteup_count], '底下评论数': [comment_count],
             '回答内容': [content]})
        df = pd.concat([df, dataFrame])
        time.sleep(random.uniform(2,3))

# %%
df
# Out:
#          知乎作者                              作者id                 回答时间   赞同数  \
# 0        持续低熵  90aa5cb28702761bf193d01bb4dc7773  2021-09-26 06:55:32  3624
# 0       kk的世界  b6c2ed7c2b68315b94d1b9a2787b313a  2021-09-26 21:45:35  3883
# 0        紫玉茶海  112378f80b394ec2e890a784496786ab  2021-09-29 17:28:47   242
# 0        花猫哥哥  4d0b7699a319a87ba261992041eed8a4  2021-09-28 21:29:40  2889
# 0          福窦  c071ca149d46828892d14ac7ed19fd6c  2021-09-29 19:35:46   312
# 0        花猫哥哥  4d0b7699a319a87ba261992041eed8a4  2021-09-28 21:29:40  2889
# 0    771  孟晚舟获释，自然是中美交涉的结果。一些小朋友不懂，以为是中国向美国做出了什么妥协，才换来孟晚...
# 0    260  孟晚舟个人对华为影响很小，很久之前公认的接班人李一男离开也没对华为造成影响。孟晚舟之前是华为...
# 0     57  孟晚舟回来了，她在飞机上发表了感谢祖国的感言。很显然，她自己也知道，这个时间节点被放回来，就...
# 0    582  民运人士在孟晚舟回国这件事上的表现非常盎撒：双标。最多的民运话术就是“她在加拿大的大里住了三...
# 0      7  继续关孟晚舟，美国捞不到任何好处，干脆找个台阶下，把人放走得了。关不关孟晚舟，华为都不会屈服...
# 0    582  民运人士在孟晚舟回国这件事上的表现非常盎撒：双标。最多的民运话术就是“她在加拿大的大里住了三...
# 0      7  继续关孟晚舟，美国捞不到任何好处，干脆找个台阶下，把人放走得了。关不关孟晚舟，华为都不会屈服...
# 0    472  意义重大。现在华为对国家忠心，是因为有任正非在。可任正非已经快了。如果有一天任正非不在了，华...
# 0     65  我以为，有此经历，如果将来任正非让孟晚舟接班，华为未来就有了一个心智刚强的领导人，对国家而言...
# 0     13                          两岸猿声啼不住，轻舟已过万重山。李白《早发白帝城》
# 0     65  我以为，有此经历，如果将来任正非让孟晚舟接班，华为未来就有了一个心智刚强的领导人，对国家而言...
# 0     13                          两岸猿声啼不住，轻舟已过万重山。李白《早发白帝城》
# 0     18  孟晚舟女士释放回国，对华为而言，更多的是士气的振奋与鼓舞国家极力帮助孟晚舟回国，说明国家认可...
# 0      4  就说一直追着黑的立党老师吧。知乎键政任都知道，立党家有四套房。但是这四套房理论是归全天津人所...
# 0    135  谢邀如果一直回不来，那么华为会寒心同时，其他企业搞自主研发的念头，可能也会就此打住，大家还不...
# 0      4  就说一直追着黑的立党老师吧。知乎键政任都知道，立党家有四套房。但是这四套房理论是归全天津人所...
# 0    135  谢邀如果一直回不来，那么华为会寒心同时，其他企业搞自主研发的念头，可能也会就此打住，大家还不...
# 0     94  一个超级大国动用一切资源打压一个企业，现实背景就是敌我力量悬殊，可是帝国最后竟然没有达成目的...
# 0   1530  借热度说句其他的。总有人一惊一乍的孟晚舟在加拿大住豪宅世界强的，住个豪宅是个很惊奇的事情吗？...
# 0      2                      孟晚舟回国的航班为何要绕道北极？刻意避开美国到底有何玄机？
# 0   1530  借热度说句其他的。总有人一惊一乍的孟晚舟在加拿大住豪宅世界强的，住个豪宅是个很惊奇的事情吗？...
# 0      2                      孟晚舟回国的航班为何要绕道北极？刻意避开美国到底有何玄机？
# 0    487  孟晚舟获释，最大的意义其实在中美之间。我们知道，美国制裁过日本，让当年如日中中升的日本经济增...
# 0      0  正如我们在官宣中说的，孟晚舟获释，主要源于中国政府的不懈努力。这不是客套话，也不是抢功，而是...
# 0     73  我是一个设计师，经常要跑现场，所以我常常带着两台手机，怕电量不够，或者电量够，但是坏了可以方...

# %%
with open('test.txt','w') as f:
    f.write(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-b47cf8c7c568> in <module>
#       1 with open('test.txt','w') as f:
# ----> 2     f.write(df)
#
# TypeError: write() argument must be str, not DataFrame
